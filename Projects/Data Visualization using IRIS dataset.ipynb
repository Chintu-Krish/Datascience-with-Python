# %% [markdown]
# ### Proj 05. Data Visualization using IRIS dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sample=sns.load_dataset("iris")

# %%
sample.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sample.species.value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
sample.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
## Bar plot

sns.barplot(x="species",y="sepal_length",data=sample)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
## Count plot

sns.countplot(x="species",data=sample)
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
## Box plot

sns.boxplot(data=sample)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x="species",y="sepal_width",data=sample)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
## Violin plot

sns.violinplot(x="species",y="sepal_width",data=sample)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
## strip plot

sns.stripplot(x="species",y="petal_length",data=sample)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
## swarmplot

sns.swarmplot(x="species",y="petal_length",data=sample)
# Out:
# C:\Users\Priyanka Dharshini\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
##### Distribution plots #####
## Dist plot

sns.distplot(data.petal_length)
# Out:
# C:\Users\Priyanka Dharshini\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='petal_length', ylabel='Density'>

# %%
sns.distplot(data.petal_length,kde=False)
# Out:
# C:\Users\Priyanka Dharshini\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='petal_length'>

# %%
## Joint plot

sns.jointplot(x="sepal_length",y="sepal_width",data=sample)

# %%
## Pair plot

sns.pairplot(sample)

# %%
## Rug plot

sns.rugplot(data.petal_length)
# Out:
# <AxesSubplot:xlabel='petal_length'>

# %%
##### Matrix plots #####
## Heat maps

correlation=sample.corr()
correlation
sns.heatmap(correlation,annot=True)
# Out:
# <AxesSubplot:>

# %%
##### Grids #####
## Pair Grid

a=sns.PairGrid(sample)
a.map_diag(plt.hist)
a.map_upper(plt.scatter)
a.map_lower(plt.scatter)

# %%
## Facet Grid

b=sns.FacetGrid(sample,col="species")
b.map(plt.hist,"sepal_width")

# %%
## Joint Grid

c=sns.JointGrid(x="sepal_length",y="sepal_width",data=sample)
c.plot(plt.scatter,sns.distplot)
# Out:
# C:\Users\Priyanka Dharshini\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Priyanka Dharshini\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Priyanka Dharshini\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
# ...

# %%
## Regression plot

sns.lmplot(x="sepal_length",y="sepal_width",data=sample)

# %%
## Relational plot

sns.relplot(x="sepal_length",y="sepal_width",data=sample,kind="line")

# %%
## Scatter plot

sns.scatterplot(x="sepal_length",y="sepal_width",data=sample,hue="species")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>
